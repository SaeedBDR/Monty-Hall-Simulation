# %%
import random

# %%
doors = ["Goat", "Goat", "Car"]
random.shuffle(doors)

# %%
def monty_hall(switch):
    if switch:
      available_doors = [i for i in range(3) if i not in player_choice and host_opens]
      player_choice = doors[0]
    return doors[player_choice] == "car"

# %%
remaining_doors = [i for i in range(3) if i != player_choice and doors[i] == "Goat"]
host_opens = random.choice(remaining_doors)

# %%
player_choice = random.randint(0,2)

# %%
def simulate_monty_hall(trials = 10000):
    wins_without_switch = sum(monty_hall(switch = False) for _ in range(trials))
    wins_with_switch = sum(monty_hall(switch = True) for _ in rang (trials))
    print(f"number of simulations: {trials}")
    print(f"if you don't switch: win rate= {wins_without_switch / trials: .02%}")
    print(f"if you do switch: win rate= {wins_with_switch / trials: .02%}")
